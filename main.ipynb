# %%
import streamlit as st 
import matplotlib.pyplot as plt
import numpy as np
from skimage import io
from skimage.color import rgb2gray, rgb2hsv
from skimage.transform import resize
from skimage.morphology import dilation
from skimage.restoration import inpaint
from skimage import filters
import pandas as pd
import matplotlib.dates as mdates
# Out:
# 2022-09-13 09:32:11.286 INFO    numexpr.utils: NumExpr defaulting to 4 threads.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/kaustuvchatterjee/vskp/main/vskp_data.csv')
df.to_csv('vskp_data.csv')

# %%
# !pip freeze requirements.txt
# Out:
# absl-py==1.2.0
# aiodns==3.0.0
# aiohttp==3.8.1
# aiosignal==1.2.0
# alabaster==0.7.12
# altair==4.2.0
# anyio==3.6.1
# appdirs==1.4.4
# argcomplete==2.0.0
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# arrow==1.2.1
# astroid==2.11.6
# asttokens==2.0.5
# async-generator==1.10
# async-timeout==4.0.2
# atomicwrites==1.4.0
# attrs==21.4.0
# autopep8==1.6.0
# Babel==2.9.1
# backcall==0.1.0
# Beaker==1.10.0
# beautifulsoup4==4.11.0
# binaryornot==0.4.4
# black==22.3.0
# bleach==4.0.0
# blinker==1.5
# blivet==3.4.4
# blivet-gui==2.3.0
# Bottleneck==1.3.2
# Brlapi==0.8.4
# Brotli==1.0.9
# cachetools==5.0.0
# cffi==1.15.0
# chardet==4.0.0
# charset-normalizer==2.0.11
# chrome-gnome-shell==0.0.0
# click==8.0.4
# cloudpickle==2.0.0
# commonmark==0.9.1
# cookiecutter==2.1.1
# coverage==6.3
# cryptography==36.0.0
# cssselect==0.9.2
# cupshelpers==1.0
# cycler==0.11.0
# dasbus==1.6
# dbus-python==1.2.18
# decorator==5.1.1
# defusedxml==0.7.1
# diff-match-patch==20200713
# dill==0.3.4
# distlib==0.3.4
# distro==1.6.0
# docutils==0.17.1
# entrypoints==0.3
# et-xmlfile==1.0.1
# executing==0.8.2
# fastjsonschema==2.15.3
# fedora-third-party==0.10
# filelock==3.3.1
# flake8==4.0.1
# flaky==3.7.0
# fonttools==4.29.1
# fros==1.1
# frozenlist==1.3.1
# fs==2.4.11
# fsspec==2022.7.1
# future==0.18.2
# gcsfs==0.6.2
# gitdb==4.0.9
# GitPython==3.1.27
# google-auth==2.10.0
# google-auth-oauthlib==0.4.1
# gpg==1.15.1
# greenlet==1.1.2
# h5py==3.7.0
# helpdev==0.6.10
# html5lib==1.1
# humanize==3.13.1
# idna==3.3
# imageio==2.19.5
# imagesize==1.2.0
# importlib-metadata==4.10.1
# inflection==0.5.1
# iniconfig==1.1.1
# intervaltree==3.1.0
# ipykernel==6.6.1
# ipython==8.3.0
# ipython_genutils==0.2.0
# ipywidgets==7.7.1
# isort==5.10.1
# jdcal==1.4.1
# jedi==0.17.2
# jeepney==0.7.1
# jellyfish==0.8.3
# Jinja2==3.0.3
# jinja2-time==0.2.0
# joblib==1.1.0
# JPype1==1.4.0
# json5==0.9.8
# jsonschema==3.2.0
# jupyter-client==7.1.2
# jupyter-core==4.9.1
# jupyter-kite==2.0.2
# jupyter-server==1.17.0
# jupyterlab==3.4.2
# jupyterlab-pygments==0.1.2
# jupyterlab-server==2.13.0
# jupyterlab-tabnine==0.0.24
# jupyterlab-widgets==1.1.1
# keyring==23.8.2
# kiwisolver==1.4.1
# langtable==0.0.58
# lazy-object-proxy==1.7.1
# libcomps==0.1.18
# libsass==0.20.0
# lxml==4.7.1
# m2r==0.2.1
# Mako==1.1.4
# MarkupSafe==2.1.1
# matplotlib==3.5.3
# matplotlib-inline==0.1.2
# mccabe==0.6.1
# mediapipe==0.8.10.1
# mistune==0.8.4
# multidict==5.1.0
# munkres==1.1.2
# mypy-extensions==0.4.3
# nbclassic==0.3.7
# nbclient==0.5.10
# nbconvert==6.5.0
# nbformat==5.4.0
# nest-asyncio==1.5.4
# netifaces==0.11.0
# networkx==2.8.5
# nftables==0.1
# notebook==6.4.11
# notebook-shim==0.1.0
# numexpr==2.8.1
# numpy==1.22.0
# numpydoc==1.1.0
# oauthlib==3.0.2
# odfpy==1.4.1
# olefile==0.46
# opencv-contrib-python==4.6.0.66
# opencv-python==4.6.0.66
# openpyxl==3.0.3
# packaging==21.3
# pandas==1.3.5
# pandas-datareader==0.10.0
# pandocfilters==1.5.0
# parso==0.7.1
# Paste==3.5.0
# pathspec==0.9.0
# pexpect==4.8.0
# pickleshare==0.7.5
# pid==2.2.3
# Pillow==9.1.0
# platformdirs==2.3.0
# pluggy==1.0.0
# ply==3.11
# poyo==0.5.0
# productmd==1.33
# prometheus-client==0.14.1
# prompt-toolkit==3.0.24
# protobuf==3.20.1
# psutil==5.8.0
# psycopg2==2.9.1
# ptyprocess==0.6.0
# pure-eval==0.2.2
# pvlib==0.9.1
# pwquality==1.4.4
# py==1.11.0
# pyarrow==8.0.0
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycairo==1.21.0
# pycares==4.1.2
# pycodestyle==2.8.0
# pycparser==2.20
# pycrypto==2.6.1
# pycups==2.0.1
# pycurl==7.45.1
# pydeck==0.7.1
# pydocstyle==6.0.0
# pyenchant==3.2.2
# pyflakes==2.4.0
# Pygments==2.11.2
# PyGObject==3.42.1
# PyJWT==2.4.0
# pykickstart==3.36
# pylint==2.13.7
# pyls-spyder==0.4.0
# Pympler==1.0.1
# PyMySQL==0.10.1
# pyNetLogo==0.4.2
# pyOpenSSL==21.0.0
# pyparsing==2.4.7
# pyparted==3.12.0
# PyQt5==5.15.6
# PyQt5-sip==12.9.0
# PyQtWebEngine==5.15.4
# pyrsistent==0.18.1
# PySide2==5.15.2.1
# PySocks==1.7.1
# pytesseract==0.3.9
# pytest==6.2.5
# pytest-cov==3.0.0
# pytest-timeout==2.1.0
# python-augeas==1.1.0
# python-dateutil==2.8.1
# python-jsonrpc-server==0.4.0
# python-language-server==0.36.2
# python-lsp-black==1.0.0
# python-lsp-jsonrpc==1.0.0
# python-lsp-server==1.3.3
# python-meh==0.50
# python-slugify==4.0.1
# pytz==2022.2
# pytz-deprecation-shim==0.1.0.post0
# pyudev==0.22.0
# PyWavelets==1.3.0
# pyxdg==0.27
# PyYAML==6.0
# pyzmq==22.3.0
# QDarkStyle==3.0.2
# qstylizer==0.2.0
# QtAwesome==1.1.1
# qtconsole==5.2.2
# QtPy==2.0.0
# qtsass==0.3.0
# regex==2022.6.2
# requests==2.27.1
# requests-file==1.5.1
# requests-ftp==0.3.1
# requests-oauthlib==1.3.0
# rich==12.5.1
# rope==0.22.0
# rpm==4.17.1
# rsa==4.8
# Rtree==0.9.7
# scikit-image==0.19.3
# scikit-learn==1.1.1
# scipy==1.8.1
# scour==0.38.1
# seaborn==0.11.2
# SecretStorage==3.3.1
# selinux==3.3
# semver==2.13.0
# Send2Trash==1.8.0
# sepolicy==3.3
# setools==4.4.0
# shiboken2==5.15.2.1
# simpleaudio==1.0.4
# simpleline==1.9.0
# six==1.16.0
# sklearn==0.0
# smmap==5.0.0
# sniffio==1.2.0
# snowballstemmer==1.9.0
# sortedcontainers==2.4.0
# sos==4.3
# soupsieve==2.3.1
# Sphinx==4.4.0
# sphinx-rtd-theme==1.0.0
# sphinxcontrib-applehelp==1.0.2
# sphinxcontrib-devhelp==1.0.2
# sphinxcontrib-htmlhelp==2.0.0
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.3
# sphinxcontrib-serializinghtml==1.1.5
# spyder==5.2.1
# spyder-kernels==2.2.1
# SQLAlchemy==1.4.40
# stack-data==0.1.4
# streamlit==1.12.0
# systemd-python==234
# tables==3.7.0
# tabulate==0.8.10
# Tempita==0.5.2
# terminado==0.15.0
# testpath==0.5.0
# text-unidecode==1.3
# textdistance==4.2.0
# threadpoolctl==3.1.0
# three-merge==0.1.1
# tifffile==2022.5.4
# tinycss2==1.1.1
# toml==0.10.2
# tomli==1.2.3
# toolz==0.12.0
# torbrowser-launcher==0.3.5
# tornado==6.1
# tox==3.25.1
# traitlets==5.1.1
# typed-ast==1.5.4
# typing_extensions==4.3.0
# tzdata==2022.1
# tzlocal==4.2
# ujson==5.4.0
# urllib3==1.26.8
# validators==0.20.0
# virtualenv==20.13.4
# watchdog==2.1.6
# wcwidth==0.2.5
# webencodings==0.5.1
# websocket-client==1.3.2
# widgetsnbextension==3.6.1
# wrapt==1.14.0
# wurlitzer==1.0.3
# xarray==2022.6.0
# xlrd==2.0.1
# XlsxWriter==3.0.3
# xlwt==1.3.0
# yapf==0.32.0
# yarl==1.7.2
# youtube-dl==2021.12.17
# zipp==3.7.0
